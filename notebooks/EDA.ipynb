# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("../data/bangkok_traffy.csv")

# %%
df.head()
# Out:
#      ticket_id                 type                  organization  \
# 0  2021-9LHDM6                   {}                           NaN
# 1  2021-FYJTFP          {ความสะอาด}                    เขตบางซื่อ
# 2  2021-8GKAR9              {สายไฟ}     ยังไม่มีหน่วยงานรับผิดชอบ
# 3  2021-AFPUXZ          {ถนน,สะพาน}                           NaN
# 4  2021-CGPMUN  {น้ำท่วม,ร้องเรียน}  เขตประเวศ,ฝ่ายโยธา เขตประเวศ
#
#                                              comment  \
# 0                                           ไม่มีภาพ
# 1                                            ขยะเยอะ
# 2  1. เถาวัลย์งอดบนสายไฟ ผมกลัวว่าต่อไปจะเอาออกยา...
# 3  1 ซ่อมทางเท้าหลังคืนพื้นที่จากการปรับปรุงสะพาน...
# 4  น้ำท่วมเวลาฝนตกและทะลุเข้าบ้านเดือดร้อนมากทุกๆ...
#
#                                                photo  \
# 0  https://storage.googleapis.com/traffy_public_b...
# 1  https://storage.googleapis.com/traffy_public_b...
# 2  https://storage.googleapis.com/traffy_public_b...
# ...

# %%
df.isna().sum()
# Out:
# ticket_id          2636
# type                 97
# organization       1000
# comment            2636
# photo                94
# photo_after       87388
# coords                0
# address            2636
# subdistrict          72
# district             74
# province             25
# timestamp             0
# state                 0
# star             171127
# count_reopen     117697
# last_activity         0
# dtype: int64

# %%
len(df)
# Out:
# 269925

# %%
df.province.unique()
# Out:
# array(['กรุงเทพมหานคร', 'จังหวัดกรุงเทพมหานคร', 'นนทบุรี', 'นครปฐม',
#        'ศรีสะเกษ', 'สมุทรปราการ', 'เชียงใหม่', 'ปทุมธานี', 'สมุทรสาคร',
#        'อ่างทอง', 'ชลบุรี', 'ภูเก็ต', 'ยะลา', 'ลำปาง', 'พระนครศรีอยุธยา',
#        'ตาก', 'อุบลราชธานี', 'ฉะเชิงเทรา', 'ขอนแก่น', 'นครศรีธรรมราช',
#        'เชียงราย', nan, 'จันทบุรี', 'สงขลา', 'นครราชสีมา', 'ปราจีนบุรี',
#        'กาฬสินธุ์', 'พิจิตร', 'อุตรดิตถ์', 'ราชบุรี', 'กาญจนบุรี',
#        'ชัยนาท', 'อุทัยธานี', 'สุพรรณบุรี', 'ลพบุรี', 'นครสวรรค์',
#        'นครนายก', 'สกลนคร', 'สตูล', 'อุดรธานี', 'เพชรบุรี', 'ตรัง',
#        'สุรินทร์', 'อำนาจเจริญ', 'บุรีรัมย์', 'สุโขทัย', 'สุราษฎร์ธานี',
#        'พิษณุโลก', 'มหาสารคาม', 'ร้อยเอ็ด', 'แพร่', 'สมุทรสงคราม',
#        'สิงห์บุรี', 'ลำพูน', 'ระยอง', 'ยโสธร', 'นครพนม', 'น่าน',
#        'หนองบัวลำภู', 'จังหวัดชลบุรี', 'จังหวัดจังหวัด กรุงเทพมหานคร',
#        'จังหวัดพระนครศรีอยุธยา', 'จังหวัดสมุทรปราการ', 'จังหวัดLac',
#        'จังหวัดฉะเชิงเทรา', 'จังหวัดนนทบุรี', 'จังหวัดBangkok',
# ...

# %%
df.district.unique()
# Out:
# array(['บางพลัด', nan, 'ห้วยขวาง', 'บางรัก', 'ประเวศ', 'ลาดกระบัง',
#        'สวนหลวง', 'มีนบุรี', 'สาทร', 'คลองสามวา', 'ราชเทวี', 'ภาษีเจริญ',
#        'ป้อมปราบศัตรูพ่าย', 'ธนบุรี', 'ดอนเมือง', 'ลาดพร้าว', 'คลองเตย',
#        'ปทุมวัน', 'จตุจักร', 'เมืองนนทบุรี', 'ราษฎร์บูรณะ', 'หนองแขม',
#        'พระนคร', 'บางคอแหลม', 'ดินแดง', 'ตลิ่งชัน', 'บางเขน',
#        'วังทองหลาง', 'คลองสาน', 'คันนายาว', 'บางกอกน้อย', 'บางกะปิ',
#        'ทุ่งครุ', 'จอมทอง', 'บางขุนเทียน', 'บางบอน', 'หลักสี่', 'บางแค',
#        'วัฒนา', 'บางกอกใหญ่', 'บางนา', 'บางซื่อ', 'ดุสิต', 'พญาไท',
#        'สัมพันธวงศ์', 'บึงกุ่ม', 'สะพานสูง', 'สายไหม', 'พุทธมณฑล',
#        'ทวีวัฒนา', 'หนองจอก', 'ยานนาวา', 'พระโขนง', 'บางกรวย', 'บางพลี',
#        'บางใหญ่', 'ปากเกร็ด', 'เมืองเชียงใหม่', 'พระประแดง',
#        'เมืองสมุทรปราการ', 'ลำลูกกา', 'เมืองสมุทรสาคร', 'บางบ่อ',
#        'บางเสาธง', 'คลองหลวง', 'แม่แจ่ม', 'เมืองปทุมธานี', 'ไชโย',
#        'กระทุ่มแบน', 'บางละมุง', 'ถลาง', 'เบตง', 'แม่เมาะ', 'เมืองนครปฐม',
# ...
